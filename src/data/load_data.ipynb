# %%
import pyarrow.parquet as pq
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot

file_path = pq.ParquetFile('../../data/lectures_horaries_ABD.parquet')

table = file_path.read()
df = table.to_pandas()

# %%
print(df.head())  # First 5 rows

# %%
print(df.columns) # Column names

# %%
print(df.info())  # Data types and missing values

# %%
waterFlow = df['Índex de lectura (L/h)/Índice de lectura (L/h)/Reading index (L/h)'] # Flow of the water

# %%
waterFlowGradient = np.gradient(waterFlow, axis=0)

# %%
plot.hist(waterFlowGradient)
plot.yscale('log')
plot.show()

# %%
plot.plot(waterFlowGradient)
plot.show()

# %%
waterFlowDiff = np.diff(waterFlow, 1, 0)

# %%
plot.hist(waterFlowDiff)
plot.yscale('log')
plot.show()

# %%
plot.plot(waterFlowDiff)
plot.show()

# %%
np.mean(waterFlow) # Mean of the flow of the water

# %%
np.median(waterFlow) # Median of the flow of the water

# %%
# Plot of the flow of water to see the distribution better
plot.hist(waterFlow)
plot.yscale('log')
plot.show()

# %%
#variables to study and plot

# Policies
policies = df['Pòlissa/Póliza/Policy'].unique()
policiesNumber = df['Pòlissa/Póliza/Policy'].nunique()
waterFlowPolicies = df[['Pòlissa/Póliza/Policy', 'Índex de lectura (L/h)/Índice de lectura (L/h)/Reading index (L/h)']].groupby(['Pòlissa/Póliza/Policy']).sum()['Índex de lectura (L/h)/Índice de lectura (L/h)/Reading index (L/h)'].to_numpy()

# %%
# Tech types
techTypes = df['Tecnologia/Tecnología/Technology'].unique()
waterFlowTech = df[['Tecnologia/Tecnología/Technology', 'Índex de lectura (L/h)/Índice de lectura (L/h)/Reading index (L/h)']].groupby(['Tecnologia/Tecnología/Technology']).sum()['Índex de lectura (L/h)/Índice de lectura (L/h)/Reading index (L/h)'].to_numpy()

# %%
# Diameters
diameters = df['Diàmetre comptador (cm)/Diámetro contador (cm)/Counter diameter (cm)'].unique()
waterFlowDiameter = df[['Diàmetre comptador (cm)/Diámetro contador (cm)/Counter diameter (cm)', 'Índex de lectura (L/h)/Índice de lectura (L/h)/Reading index (L/h)']].groupby(['Diàmetre comptador (cm)/Diámetro contador (cm)/Counter diameter (cm)']).sum()['Índex de lectura (L/h)/Índice de lectura (L/h)/Reading index (L/h)'].to_numpy()

# %%
# Use
use = df['Ús/Uso/Use'].unique()
useNumber = df['Ús/Uso/Use'].nunique()
waterFlowUse = df[['Ús/Uso/Use', 'Índex de lectura (L/h)/Índice de lectura (L/h)/Reading index (L/h)']].groupby(['Ús/Uso/Use']).sum()['Índex de lectura (L/h)/Índice de lectura (L/h)/Reading index (L/h)'].to_numpy()

# %%
# Housing
housing = df['Tipus d\'habitatge/Tipo de vivienda/Type of housing'].unique()
housingNumber = df['Tipus d\'habitatge/Tipo de vivienda/Type of housing'].nunique()
waterFlowHousing = df[['Tipus d\'habitatge/Tipo de vivienda/Type of housing', 'Índex de lectura (L/h)/Índice de lectura (L/h)/Reading index (L/h)']].groupby(['Tipus d\'habitatge/Tipo de vivienda/Type of housing']).sum()['Índex de lectura (L/h)/Índice de lectura (L/h)/Reading index (L/h)'].to_numpy()

# %%
# Date
date = df['Data/Fecha/Date'].unique()
dateNumber = df['Data/Fecha/Date'].nunique()
waterFlowDate = df[['Data/Fecha/Date', 'Índex de lectura (L/h)/Índice de lectura (L/h)/Reading index (L/h)']].groupby(['Data/Fecha/Date']).sum()['Índex de lectura (L/h)/Índice de lectura (L/h)/Reading index (L/h)'].to_numpy()

# %%
# Covariance (and correlation) of the flow of water and policy
np.cov(range(policiesNumber), waterFlowPolicies)

# %%
# Plot of the relation between policy and flow of water
plot.plot(waterFlowPolicies)
plot.show()

#showPlot(df['Pòlissa/Póliza/Policy'], df['Índex de lectura (L/h)/Índice de lectura (L/h)/Reading index (L/h)'], 0)

# %%
# Covariance (and correlation) between the technology and the flow of water
t1 = np.array([], dtype = int)
for i in range(len(techTypes)):
    t1 = np.append(t1, ord(techTypes[i]))
np.cov(t1, waterFlowTech)

# %%
# Plot to visualize the relationship between technology and flow of water
plot.bar(waterFlowTech)
plot.show()

# %%
# Covariance (and correlation) of the flow of water and the counter diameter
np.cov(diameters, waterFlowDiameter)

# %%
# Plot to visualize the relation between the counter diameter and the flow of water
plot.bar(diameters, waterFlowDiameter)
plot.yscale('log')
plot.show()

# %%
# Covariance (and correlation) of the flow of water and the counter diameter
np.cov(range(useNumber), waterFlowUse)

# %%
# Plot of the flow of water and use type
plot.bar(use, waterFlowUse)
plot.show()

# %%
# Covariance (and correlation) of the flow of water and the counter diameter
np.cov(range(housingNumber), waterFlowHousing)

# %%
# Logarithmic plot of the correlation between the type of housing and flow of water to see a correlation
plot.bar(housing, waterFlowHousing)
plot.yscale('log')
plot.show()

# %%
np.cov(date, waterFlowDate)

# %%
# Covariance (and correlation) of the flow of water and the date
np.cov(date, waterFlowDate)

# %%
### Takes too long to plot anything!!
# Plot to see the relation between the date and flow of water
plot.bar(date, waterFlowDate)
plot.show()
